# %% [markdown]
# # Durge Sanjeev

# %% [markdown]
# # Lets Grow More

# %% [markdown]
# # Data Science Intern LGMVIPAUG21

# %% [markdown]
# Prediction using Decision Tree  Algorithm :
#
# Create the Decision Tree classifier and visualize it graphically.
#
# The purpose is if we feed any new data to this classifier, it would be able to  predict the right class accordingly.
#
# Dataset : https://bit.ly/3kXTdox

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_iris

# %% [markdown]
# # Importing the dataset

# %%
iris_data = load_iris()
iris_df = pd.DataFrame(iris_data.data, columns = iris_data.feature_names)

# %%
iris_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
iris_df['target'] = iris_data.target
iris_df                                  #concatinated the target column in the dataframe
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# ...

# %% [markdown]
# # Checking for null values

# %%
iris_df.isna().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# target               0
# dtype: int64

# %%
iris_df.shape
# Out:
# (150, 5)

# %%
iris_df.tail(10)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 140                6.7               3.1                5.6               2.4
# 141                6.9               3.1                5.1               2.3
# 142                5.8               2.7                5.1               1.9
# 143                6.8               3.2                5.9               2.3
# 144                6.7               3.3                5.7               2.5
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 140       2
# 141       2
# 142       2
# 143       2
# 144       2
# 145       2
# 146       2
# ...

# %%
feat_clmn = [x for x in iris_df.columns if x!="target"]
feat_clmn
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
x= iris_df[feat_clmn]
x
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
y= iris_df["target"]
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: target, Length: 150, dtype: int32

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x,y, random_state = 100, test_size = 0.30)

# %%
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (105, 4)
# (45, 4)
# (105,)
# (45,)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier()
model.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
Y_pred = model.predict(X_test)
Y_pred
# Out:
# array([2, 0, 2, 0, 2, 2, 0, 0, 2, 0, 0, 2, 0, 0, 2, 1, 1, 2, 2, 2, 2, 0,
#        2, 0, 1, 2, 1, 0, 1, 2, 1, 1, 1, 0, 0, 1, 0, 1, 2, 2, 0, 1, 2, 2,
#        0])

# %%
data = pd.DataFrame({"Actual":Y_test,"Predicted":Y_pred})
data.head()
# Out:
#      Actual  Predicted
# 128       2          2
# 11        0          0
# 118       2          2
# 15        0          0
# 123       2          2

# %%
from sklearn.metrics import accuracy_score
from sklearn.tree import plot_tree
from sklearn import tree

# %%
accuracy_score(Y_test,Y_pred)
# Out:
# 0.9555555555555556

# %%
feat_name = ["Sepal length", "Sepal width", "Petal length", "Petal width"]
trg_name = ["Setosa", "Versicolor", "Virginica"]
plot_tree(model,feature_names = feat_name, class_names= trg_name , filled = True)
# Out:
# [Text(133.92000000000002, 195.696, 'Petal length <= 2.45\ngini = 0.664\nsamples = 105\nvalue = [34, 39, 32]\nclass = Versicolor'),
#  Text(100.44000000000001, 152.208, 'gini = 0.0\nsamples = 34\nvalue = [34, 0, 0]\nclass = Setosa'),
#  Text(167.40000000000003, 152.208, 'Petal width <= 1.65\ngini = 0.495\nsamples = 71\nvalue = [0, 39, 32]\nclass = Versicolor'),
#  Text(66.96000000000001, 108.72, 'Petal length <= 5.0\ngini = 0.136\nsamples = 41\nvalue = [0, 38, 3]\nclass = Versicolor'),
#  Text(33.480000000000004, 65.232, 'gini = 0.0\nsamples = 37\nvalue = [0, 37, 0]\nclass = Versicolor'),
#  Text(100.44000000000001, 65.232, 'Sepal length <= 6.05\ngini = 0.375\nsamples = 4\nvalue = [0, 1, 3]\nclass = Virginica'),
#  Text(66.96000000000001, 21.744, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = Versicolor'),
#  Text(133.92000000000002, 21.744, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]\nclass = Virginica'),
# ...

# %%
model2= DecisionTreeClassifier().fit(x,y)

# %%
plt.figure(figsize = (20,15))
tree = tree.plot_tree(model2, feature_names = feat_name, class_names = targ_name ,filled = True)
